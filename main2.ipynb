# %%
import pandas as pd
data_df = pd.DataFrame(
    {
        "sales": [
            [0, 4, 26, 80, 100, 40],
            [80, 20, 80, 35, 40, 100],
            [10, 20, 80, 80, 70, 0],
            [10, 100, 20, 100, 30, 100],
        ],
    }
)

# %%
df = pd.read_csv('Discord-Analysis.csv')
df2 = df.sort_values(by="6-Months",ascending=False)
df2.head(15)
# Out:
#      Unnamed: 0                   Month  2022-07  2022-08  2022-09  2022-10  \
# 246         167          midjourney app     15.5    29.50    19.50      7.6
# 328         168             chatgpt app      0.0     0.00     0.00      0.0
# 380          84               kenny pfp      0.0     5.00     2.25      5.4
# 385          85    kenny south park pfp      0.0     0.00     0.00     11.6
# 387          94          south park pfp      9.0     5.25     5.00      6.0
# 395         384        steam sales 2023      0.0     5.25     2.00      1.6
# 351          19     temu discord server     13.0    14.25    14.25      0.0
# 320         394           steam lawsuit      1.0     2.75     2.25      7.6
# 334         492     chatgpt discord bot      0.0     0.00     8.75      8.4
# 349         493    chat gpt discord bot      0.0     0.00    11.50      5.6
# 366         501     discord ai chat bot     10.5     9.50    18.75      7.6
# ...

# %%
df_12M = df.iloc[:,-16:-4]
df_Keywords = df.iloc[:, 1:2]
df_Sum = df.iloc[:, -1:]
df_6M = df.iloc[:, -4:-3]
df_3M = df.iloc[:, -3:-2]
df_1M = df.iloc[:, -2:-1]
print(df_Keywords)
# Out:
#                       Month
# 0          emoji copy paste
# 1      emoji copy and paste
# 2                emoji copy
# 3                   discord
# 4            font generator
# ..                      ...
# 521   hogwarts legacy steam
# 522  steam winter sale 2022
# 523     steam deck giveaway
# 524            steam replay
# 525       steam replay 2022
#
# [526 rows x 1 columns]

# %%
def df2arr(df):
    arr = df.to_numpy()
    list1 = []
    for i in arr:
        for j in i:
            list1.append(j)
    return list1

# %%
df_12M.head()
# Out:
#    2022-08  2022-09  2022-10  2022-11  2022-12  2023-01  2023-02  2023-03  \
# 0    90.25     94.0     93.0    93.75    91.75     91.8    93.50    96.00
# 1    86.25     93.5     93.4    93.50    91.25     90.8    93.50    95.50
# 2    87.75     93.0     90.4    91.00    90.75     89.0    90.75    93.50
# 3    94.00     85.5     82.6    82.00    85.50     87.6    87.75    91.25
# 4    81.50     80.5     82.8    80.75    87.50     87.6    90.25    90.75
#
#    2023-04  2023-05  2023-06    2023-07
# 0     95.4    95.50    87.75  84.333333
# 1     94.4    91.50    82.75  79.000000
# 2     92.2    92.75    85.25  84.666667
# 3     90.0    86.25    96.75  92.000000
# 4     93.4    97.00    96.75  91.000000

# %%
arr_12M, arr_Keywords, arr_Sum, arr_6M, arr_3M, arr_1M = [],[],[],[],[],[]
arr_12M = df2arr(df_12M)
arr_6M = df2arr(df_6M)
arr_3M = df2arr(df_3M)
arr_1M = df2arr(df_1M)
arr_Sum = df2arr(df_Sum)
arr_Keywords = df2arr(df_Keywords)

print(arr_6M)
# Out:
# [-2.07, -12.05, -2.78, 26.8, 58.5, 14.17, 21.58, -21.42, -39.77, 41.03, -29.17, 14.37, -3.52, -3.02, 47.03, 4.0, 22.35, -9.95, -9.95, 37.77, 39.75, 88.55, -9.82, -16.95, -27.93, -5.35, 12.8, -44.05, -16.87, -25.55, -5.12, -25.98, 10.23, 20.8, 62.43, 77.87, 16.57, 18.02, 38.05, -34.45, -85.33, 28.72, -33.1, -29.35, -15.42, 47.03, -0.68, -36.45, -41.63, 16.35, -30.98, -88.57, -42.32, 30.85, -11.12, 83.83, 42.02, 46.45, 30.3, 20.87, -25.5, 13.07, -6.18, -25.52, -21.37, 6.4, -88.4, 29.42, 42.63, 52.63, 7.25, -1.18, 62.98, 20.1, -18.45, -82.88, 111.88, 29.4, 37.78, -146.88, 22.82, -29.27, -53.65, 66.2, 71.25, -78.77, -70.23, -34.12, 23.65, 49.82, -23.7, -10.53, 63.33, 24.7, 28.85, -32.42, 27.6, 28.63, -10.27, -20.45, 23.37, -48.58, 62.28, -75.62, 6.22, -46.0, -79.55, -94.68, 47.5, 45.88, -93.28, 46.78, -37.28, 35.8, 38.12, 62.93, 60.6, 96.65, -95.18, -12.32, 37.35, 191.02, 15.75, -90.27, 33.68, -8.07, 17.32, 3.73, 75.43, 37.72, -47.85, 57.0, 48.12, -18.83, 64.53, 112.5, -72.83, -70.25, -5
# ...

# %%
arr = df_dropped.to_numpy()
list1 = []
# print(arr)
for i in arr:
    list1.append(i)
print(list1)
# Out:
# [array([85.        , 72.25      , 72.        , 70.75      , 68.75      ,
#        70.6       , 79.        , 71.25      , 71.        , 64.25      ,
#        74.        , 78.66666667]), array([75.25, 60.25, 60.4 , 61.  , 51.  , 63.2 , 66.75, 73.  , 70.2 ,
#        59.25, 69.5 , 93.  ]), array([44. , 60.5, 53. , 57. , 40. , 30. , 25. , 29. , 25.6, 21. , 28. ,
#        26. ]), array([66.        , 46.5       , 56.2       , 65.25      , 73.        ,
#        63.6       , 77.5       , 74.5       , 62.4       , 66.        ,
#        80.75      , 72.33333333]), array([86.        , 85.5       , 89.2       , 84.        , 87.        ,
#        86.2       , 89.        , 88.        , 91.4       , 91.25      ,
#        87.75      , 84.66666667]), array([58.        , 59.25      , 52.8       , 57.        , 46.75      ,
#        61.4       , 56.        , 56.5       , 60.        , 59.25      ,
#        68.        , 76.33333333]), array([76.5 , 69.  , 64.  , 60.75, 67.25, 69.6 , 66.75, 69.75, 76.2 ,
# ...

# %%
arr = df_dropped2.to_numpy()
list2 = []
# print(arr)
for i in arr:
    list2.append(i)
# print(list2)
# Out:
# [array(['discord bot'], dtype=object), array(['how to make a discord server'], dtype=object), array(['discord on xbox'], dtype=object), array(['how to delete discord server'], dtype=object), array(['emoji'], dtype=object), array(['discord emoji server'], dtype=object), array(['emoji discord'], dtype=object), array(['minecraft discord'], dtype=object), array(['minecraft discord server'], dtype=object), array(['minecraft server'], dtype=object), array(['discord bots'], dtype=object), array(['discord server bots'], dtype=object), array(['discord servers'], dtype=object), array(['how to join discord server'], dtype=object), array(['discord template server'], dtype=object), array(['discord template'], dtype=object), array(['what is a discord server'], dtype=object), array(['find discord server'], dtype=object), array(['discord server names'], dtype=object), array(['temu discord server'], dtype=object), array(['diablo 4 discord server'], dtype=object), array(['soundboard discord'], dtype=o
# ...

# %%
length_keywords = len(arr_Keywords)
length_12M = len(arr_12M)
length_6M = len(arr_6M)
length_3M = len(arr_3M)
length_1M = len(arr_1M)
length_sum = len(arr_Sum)

print(f"Length of Keywords array: {length_keywords}")
print(f"Length of 12M array: {length_12M}")
print(f"Length of 6M array: {length_6M}")
print(f"Length of 3M array: {length_3M}")
print(f"Length of 1M array: {length_1M}")
print(f"Length of Sum array: {length_sum}")
# Out:
# Length of Keywords array: 526
# Length of 12M array: 526
# Length of 6M array: 526
# Length of 3M array: 526
# Length of 1M array: 526
# Length of Sum array: 526

# %%
print(arr_12M)
# Out:
# [array([90.25      , 94.        , 93.        , 93.75      , 91.75      ,
#        91.8       , 93.5       , 96.        , 95.4       , 95.5       ,
#        87.75      , 84.33333333]), array([86.25, 93.5 , 93.4 , 93.5 , 91.25, 90.8 , 93.5 , 95.5 , 94.4 ,
#        91.5 , 82.75, 79.  ]), array([87.75      , 93.        , 90.4       , 91.        , 90.75      ,
#        89.        , 90.75      , 93.5       , 92.2       , 92.75      ,
#        85.25      , 84.66666667]), array([94.  , 85.5 , 82.6 , 82.  , 85.5 , 87.6 , 87.75, 91.25, 90.  ,
#        86.25, 96.75, 92.  ]), array([81.5 , 80.5 , 82.8 , 80.75, 87.5 , 87.6 , 90.25, 90.75, 93.4 ,
#        97.  , 96.75, 91.  ]), array([86.        , 85.5       , 89.2       , 84.        , 87.        ,
#        86.2       , 89.        , 88.        , 91.4       , 91.25      ,
#        87.75      , 84.66666667]), array([89.5       , 82.75      , 82.        , 84.        , 87.        ,
# ...

# %%
print(arr_Keywords)
# Out:
# [array(['emoji copy paste'], dtype=object), array(['emoji copy and paste'], dtype=object), array(['emoji copy'], dtype=object), array(['discord'], dtype=object), array(['font generator'], dtype=object), array(['emoji'], dtype=object), array(['7zip'], dtype=object), array(['anime girl'], dtype=object), array(['gif'], dtype=object), array(['password manager'], dtype=object), array(['google account'], dtype=object), array(['maki'], dtype=object), array(['skull emoji'], dtype=object), array(['anime'], dtype=object), array(['text emoji'], dtype=object), array(['g2a'], dtype=object), array(['dyno'], dtype=object), array(['discord login'], dtype=object), array(['login discord'], dtype=object), array(['what is discord'], dtype=object), array(['patreon'], dtype=object), array(['google password manager'], dtype=object), array(['appstore'], dtype=object), array(['discord app'], dtype=object), array(['color picker'], dtype=object), array(['pintrest'], dtype=object), array(['reverse image search'
# ...

# %%
print(arr_6M)
# Out:
# [array([-2.07]), array([-12.05]), array([-2.78]), array([26.8]), array([58.5]), array([14.17]), array([21.58]), array([-21.42]), array([-39.77]), array([41.03]), array([-29.17]), array([14.37]), array([-3.52]), array([-3.02]), array([47.03]), array([4.]), array([22.35]), array([-9.95]), array([-9.95]), array([37.77]), array([39.75]), array([88.55]), array([-9.82]), array([-16.95]), array([-27.93]), array([-5.35]), array([12.8]), array([-44.05]), array([-16.87]), array([-25.55]), array([-5.12]), array([-25.98]), array([10.23]), array([20.8]), array([62.43]), array([77.87]), array([16.57]), array([18.02]), array([38.05]), array([-34.45]), array([-85.33]), array([28.72]), array([-33.1]), array([-29.35]), array([-15.42]), array([47.03]), array([-0.68]), array([-36.45]), array([-41.63]), array([16.35]), array([-30.98]), array([-88.57]), array([-42.32]), array([30.85]), array([-11.12]), array([83.83]), array([42.02]), array([46.45]), array([30.3]), array([20.87]), array([-25.5]), array([13
# ...

# %%
for i in arr_6M:
    for j in i:
        print(j)
# Out:
# -2.07
# -12.05
# -2.78
# 26.8
# 58.5
# 14.17
# 21.58
# -21.42
# -39.77
# 41.03
# -29.17
# 14.37
# -3.52
# -3.02
# 47.03
# 4.0
# 22.35
# -9.95
# -9.95
# 37.77
# 39.75
# 88.55
# -9.82
# -16.95
# -27.93
# -5.35
# 12.8
# -44.05
# -16.87
# -25.55
# -5.12
# -25.98
# 10.23
# 20.8
# 62.43
# 77.87
# 16.57
# 18.02
# 38.05
# -34.45
# -85.33
# 28.72
# -33.1
# -29.35
# -15.42
# 47.03
# -0.68
# -36.45
# -41.63
# 16.35
# -30.98
# -88.57
# -42.32
# 30.85
# -11.12
# 83.83
# 42.02
# 46.45
# 30.3
# 20.87
# -25.5
# 13.07
# -6.18
# -25.52
# -21.37
# 6.4
# -88.4
# 29.42
# 42.63
# 52.63
# 7.25
# -1.18
# 62.98
# 20.1
# -18.45
# -82.88
# 111.88
# 29.4
# 37.78
# -146.88
# 22.82
# -29.27
# -53.65
# 66.2
# 71.25
# -78.77
# -70.23
# -34.12
# 23.65
# 49.82
# -23.7
# -10.53
# 63.33
# 24.7
# 28.85
# -32.42
# 27.6
# 28.63
# -10.27
# -20.45
# 23.37
# -48.58
# 62.28
# -75.62
# 6.22
# -46.0
# -79.55
# -94.68
# 47.5
# 45.88
# -93.28
# 46.78
# -37.28
# 35.8
# 38.12
# 62.93
# 60.6
# 96.65
# -95.18
# -12.32
# 37.35
# ...
